# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from itertools import combinations
import shap

# %%
import pandas, numpy, shap, sklearn, matplotlib, seaborn, imblearn, joblib

print("pandas==", pandas.__version__)
print("numpy==", numpy.__version__)
print("shap==", shap.__version__)
print("scikit-learn==", sklearn.__version__)
print("matplotlib==", matplotlib.__version__)
print("seaborn==", seaborn.__version__)
print("imbalanced-learn==", imblearn.__version__)
print("joblib==", joblib.__version__)
# Out:
# pandas== 2.3.0
# numpy== 2.1.3
# shap== 0.48.0
# scikit-learn== 1.6.1
# matplotlib== 3.10.3
# seaborn== 0.13.2
# imbalanced-learn== 0.13.0
# joblib== 1.5.1

# %%
# read in the csv
cols = ["Image", "Class", "Mean", "Variance", "Standard Deviation", "Entropy", "Skewness", "Kurtosis", "Contrast", "Energy", "ASM", "Homogeneity", "Dissimilarity", "Correlation", "Coarseness"]
df = pd.read_csv("../data/Brain_Tumor.csv")
df.columns = cols

# %%
df.head()
# Out:
#     Image  Class      Mean     Variance  Standard Deviation   Entropy  \
# 0  Image1      0  6.535339   619.587845           24.891522  0.109059
# 1  Image2      0  8.749969   805.957634           28.389393  0.266538
# 2  Image3      1  7.341095  1143.808219           33.820234  0.001467
# 3  Image4      1  5.958145   959.711985           30.979219  0.001477
# 4  Image5      0  7.315231   729.540579           27.010009  0.146761
#
#    Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 0  4.276477  18.900575   98.613971  0.293314  0.086033     0.530941
# 1  3.718116  14.464618   63.858816  0.475051  0.225674     0.651352
# 2  5.061750  26.479563   81.867206  0.031917  0.001019     0.268275
# 3  5.677977  33.428845  151.229741  0.032024  0.001026     0.243851
# 4  4.283221  19.079108  174.988756  0.343849  0.118232     0.501140
#
#    Dissimilarity  Correlation     Coarseness
# 0       4.473346     0.981939  7.458341e-155
# 1       3.220072     0.988834  7.458341e-155
# 2       5.981800     0.978014  7.458341e-155
# 3       7.700919     0.964189  7.458341e-155
# 4       6.834689     0.972789  7.458341e-155

# %%
# how many class types are there
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df = df.drop(['Image', 'Variance', 'ASM'],axis=1)
df.head()
# Out:
#    Class      Mean  Standard Deviation   Entropy  Skewness   Kurtosis  \
# 0      0  6.535339           24.891522  0.109059  4.276477  18.900575
# 1      0  8.749969           28.389393  0.266538  3.718116  14.464618
# 2      1  7.341095           33.820234  0.001467  5.061750  26.479563
# 3      1  5.958145           30.979219  0.001477  5.677977  33.428845
# 4      0  7.315231           27.010009  0.146761  4.283221  19.079108
#
#      Contrast    Energy  Homogeneity  Dissimilarity  Correlation  \
# 0   98.613971  0.293314     0.530941       4.473346     0.981939
# 1   63.858816  0.475051     0.651352       3.220072     0.988834
# 2   81.867206  0.031917     0.268275       5.981800     0.978014
# 3  151.229741  0.032024     0.243851       7.700919     0.964189
# 4  174.988756  0.343849     0.501140       6.834689     0.972789
#
#       Coarseness
# 0  7.458341e-155
# 1  7.458341e-155
# 2  7.458341e-155
# 3  7.458341e-155
# 4  7.458341e-155

# %%
for label in df.columns[1:]:
    plt.hist(df[df["Class"]==1][label], color='blue', label='Positive', alpha=0.7, density=True)
    plt.hist(df[df["Class"]==0][label], color='red', label='Negative', alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
def scale_dataset(dataframe, oversample=False):
    X = dataframe[dataframe.columns[1:]].values
    y = dataframe[dataframe.columns[0]].values

    scaler = StandardScaler()
    X = scaler.fit_transform(X, y)

    if oversample:
        ros = RandomOverSampler()
        X, y = ros.fit_resample(X, y)

    data = np.hstack((X, np.reshape(y, (-1, 1))))
    return data, X, y

# %%
def KNNFunc(X_train, y_train, X_test, y_test, trial_count):
    knn_model = KNeighborsClassifier(n_neighbors=5)
    knn_model.fit(X_train, y_train)
    y_pred = knn_model.predict(X_test)
    print(f"***Trial {trial_count}***")
    print(f"kNN Results:")
    print(classification_report(y_test, y_pred))
    return

# %%
def NaiveBayesFunc(X_train, y_train, X_test, y_test, trial_count):
    nb_model = GaussianNB()
    nb_model.fit(X_train, y_train)
    y_pred = nb_model.predict(X_test)
    print(f"***Trial {trial_count}***")
    print(f"Naive Bayes Results:")
    print(classification_report(y_test, y_pred))
    return

# %%
def LogisticRegressionFunc(X_train, y_train, X_test, y_test, trial_count):
    lr_model = LogisticRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_test)
    print(f"***Trial {trial_count}***")
    print(f"Logistic Regression Results:")
    print(classification_report(y_test, y_pred))
    return

# %%
def SVMFunc(X_train, y_train, X_test, y_test, trial_count):
    svm_model = SVC()
    svm_model.fit(X_train, y_train)
    y_pred = svm_model.predict(X_test)
    print(f"***Trial {trial_count}***")
    print(f"Support Vector Machine Results:")
    print(classification_report(y_test, y_pred))
    return

# %%
noisy_features_batch_1 = ['Entropy', 'Kurtosis', 'Energy']
noisy_features_batch_2 = ['Contrast', 'Dissimilarity']

power_set_1 = [list(c) for i in range(4) for c in combinations(noisy_features_batch_1, i)]
power_set_2 = [list(c) for i in range(3) for c in combinations(noisy_features_batch_2, i)]

noisy_feature_combinations = [c1 + c2 for c1 in power_set_1 for c2 in power_set_2]

# %%
trial = 1
kept_features = ["Class", "Mean", "Standard Deviation", "Skewness", "Homogeneity", "Correlation", "Coarseness"]
for combo in noisy_feature_combinations:
    feature_set = kept_features + combo
    df_subset = df[feature_set]

    # Shuffle and split into 60/20/20
    train, valid, test = np.split(df_subset.sample(frac=1), [int(0.6*len(df_subset)), int(0.8*len(df_subset))])

    # Scale + oversample only on train
    _, X_train, y_train = scale_dataset(train, oversample=True)

    # Scale without oversample on valid/test
    _, X_valid, y_valid = scale_dataset(valid, oversample=False)
    _, X_test, y_test = scale_dataset(test, oversample=False)

    # Run all 4 models
    LogisticRegressionFunc(X_train, y_train, X_valid, y_valid, trial)
    KNNFunc(X_train, y_train, X_valid, y_valid, trial)
    NaiveBayesFunc(X_train, y_train, X_valid, y_valid, trial)
    SVMFunc(X_train, y_train, X_valid, y_valid, trial)

    trial += 1
# Out:
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 1***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       404
#            1       0.97      0.95      0.96       348
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.96      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 1***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       404
#            1       0.99      0.93      0.96       348
#
#     accuracy                           0.96       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.97      0.96      0.96       752
#
# ***Trial 1***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       404
#            1       1.00      0.93      0.96       348
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.96      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 1***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       404
#            1       0.98      0.95      0.96       348
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.96      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 2***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       446
#            1       0.95      0.94      0.94       306
#
#     accuracy                           0.95       752
#    macro avg       0.95      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
#
# ***Trial 2***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       446
#            1       0.97      0.94      0.96       306
#
#     accuracy                           0.96       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 2***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       446
#            1       0.90      0.90      0.90       306
#
#     accuracy                           0.92       752
#    macro avg       0.92      0.92      0.92       752
# weighted avg       0.92      0.92      0.92       752
#
# ***Trial 2***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       446
#            1       0.98      0.96      0.97       306
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 3***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       437
#            1       0.97      0.97      0.97       315
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 3***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       437
#            1       0.98      0.96      0.97       315
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 3***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       437
#            1       0.92      0.92      0.92       315
#
#     accuracy                           0.93       752
#    macro avg       0.93      0.93      0.93       752
# weighted avg       0.93      0.93      0.93       752
#
# ***Trial 3***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       437
#            1       0.99      0.98      0.99       315
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 4***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       420
#            1       0.99      0.95      0.97       332
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.98      0.97      0.97       752
#
# ***Trial 4***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       420
#            1       0.99      0.93      0.96       332
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 4***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       420
#            1       0.93      0.84      0.88       332
#
#     accuracy                           0.90       752
#    macro avg       0.91      0.90      0.90       752
# weighted avg       0.90      0.90      0.90       752
#
# ***Trial 4***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       420
#            1       0.99      0.95      0.97       332
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 5***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       392
#            1       0.99      0.95      0.97       360
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 5***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       392
#            1       0.99      0.96      0.97       360
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 5***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       392
#            1       0.99      0.91      0.95       360
#
#     accuracy                           0.95       752
#    macro avg       0.95      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
#
# ***Trial 5***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       392
#            1       0.99      0.96      0.97       360
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 6***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       414
#            1       0.98      0.96      0.97       338
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 6***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       414
#            1       0.98      0.95      0.97       338
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 6***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       414
#            1       0.98      0.93      0.95       338
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 6***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       414
#            1       0.98      0.96      0.97       338
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 7***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       435
#            1       0.98      0.97      0.98       317
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 7***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       435
#            1       0.96      0.97      0.96       317
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 7***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       435
#            1       0.97      0.93      0.95       317
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 7***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       435
#            1       0.97      0.97      0.97       317
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 8***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       415
#            1       0.98      0.99      0.98       337
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 8***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       415
#            1       0.99      0.98      0.99       337
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 8***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       415
#            1       0.98      0.91      0.95       337
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
#
# ***Trial 8***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       415
#            1       0.99      0.98      0.98       337
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 9***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       416
#            1       0.96      0.93      0.94       336
#
#     accuracy                           0.95       752
#    macro avg       0.95      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 9***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       416
#            1       0.99      0.93      0.96       336
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 9***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       416
#            1       0.98      0.86      0.92       336
#
#     accuracy                           0.93       752
#    macro avg       0.94      0.92      0.93       752
# weighted avg       0.93      0.93      0.93       752
#
# ***Trial 9***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       416
#            1       0.98      0.93      0.95       336
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 10***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       403
#            1       0.97      0.94      0.95       349
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 10***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       403
#            1       0.98      0.95      0.97       349
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 10***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       403
#            1       0.95      0.82      0.88       349
#
#     accuracy                           0.89       752
#    macro avg       0.90      0.89      0.89       752
# weighted avg       0.90      0.89      0.89       752
#
# ***Trial 10***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       403
#            1       1.00      0.95      0.97       349
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 11***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       427
#            1       0.97      0.96      0.97       325
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 11***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       427
#            1       0.97      0.97      0.97       325
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 11***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       427
#            1       0.91      0.83      0.87       325
#
#     accuracy                           0.89       752
#    macro avg       0.90      0.89      0.89       752
# weighted avg       0.89      0.89      0.89       752
#
# ***Trial 11***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       427
#            1       0.98      0.98      0.98       325
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 12***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       406
#            1       0.99      0.96      0.97       346
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.98      0.97      0.97       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 12***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       406
#            1       0.99      0.95      0.97       346
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 12***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       406
#            1       0.90      0.83      0.86       346
#
#     accuracy                           0.88       752
#    macro avg       0.88      0.87      0.88       752
# weighted avg       0.88      0.88      0.88       752
#
# ***Trial 12***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       406
#            1       1.00      0.96      0.98       346
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 13***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       414
#            1       0.99      0.98      0.99       338
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 13***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       414
#            1       1.00      0.98      0.99       338
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 13***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       414
#            1       0.99      0.94      0.97       338
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 13***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       414
#            1       0.99      0.98      0.99       338
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 14***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       424
#            1       0.99      0.98      0.98       328
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 14***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       424
#            1       0.98      0.96      0.97       328
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 14***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       424
#            1       0.99      0.94      0.96       328
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 14***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       424
#            1       0.99      0.98      0.98       328
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 15***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       427
#            1       0.98      0.98      0.98       325
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 15***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       427
#            1       0.99      0.98      0.98       325
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 15***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       427
#            1       0.99      0.92      0.96       325
#
#     accuracy                           0.96       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 15***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       427
#            1       0.98      0.98      0.98       325
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 16***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       419
#            1       0.97      0.98      0.98       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 16***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       419
#            1       0.99      0.96      0.98       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 16***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       419
#            1       0.98      0.92      0.95       333
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.95      0.95       752
#
# ***Trial 16***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       419
#            1       0.98      0.98      0.98       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 17***
# Logistic Regression Results:
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       419
#            1       0.99      0.97      0.98       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 17***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       419
#            1       0.97      0.96      0.97       333
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 17***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       419
#            1       0.99      0.91      0.95       333
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.95      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 17***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       419
#            1       0.98      0.97      0.98       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 18***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       427
#            1       0.99      0.99      0.99       325
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 18***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       427
#            1       0.98      0.98      0.98       325
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 18***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       427
#            1       0.99      0.90      0.94       325
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.95      0.95       752
#
# ***Trial 18***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       427
#            1       0.98      0.98      0.98       325
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 19***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       418
#            1       0.99      0.97      0.98       334
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 19***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       418
#            1       0.99      0.96      0.98       334
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 19***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       418
#            1       0.99      0.90      0.94       334
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
#
# ***Trial 19***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       418
#            1       1.00      0.97      0.98       334
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 20***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       409
#            1       1.00      0.98      0.99       343
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 20***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       409
#            1       1.00      0.97      0.98       343
#
#     accuracy                           0.98       752
#    macro avg       0.99      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 20***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       409
#            1       0.99      0.90      0.94       343
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
#
# ***Trial 20***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       409
#            1       1.00      0.98      0.99       343
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 21***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       394
#            1       1.00      0.97      0.98       358
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 21***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       394
#            1       0.99      0.97      0.98       358
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 21***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       394
#            1       0.99      0.94      0.97       358
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 21***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       394
#            1       1.00      0.97      0.98       358
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 22***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       417
#            1       0.98      0.96      0.97       335
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 22***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       417
#            1       1.00      0.96      0.98       335
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 22***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       417
#            1       0.98      0.93      0.95       335
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 22***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       417
#            1       0.98      0.96      0.97       335
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 23***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       418
#            1       0.99      0.95      0.97       334
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 23***
# kNN Results:
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       418
#            1       1.00      0.95      0.98       334
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 23***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       418
#            1       0.98      0.92      0.95       334
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 23***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       418
#            1       0.98      0.95      0.97       334
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 24***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       421
#            1       0.98      0.97      0.97       331
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 24***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       421
#            1       0.99      0.96      0.98       331
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 24***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       421
#            1       0.98      0.93      0.96       331
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 24***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       421
#            1       0.99      0.97      0.98       331
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 25***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       422
#            1       0.99      0.97      0.98       330
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 25***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       422
#            1       0.99      0.97      0.98       330
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 25***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       422
#            1       0.99      0.91      0.95       330
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.95      0.96       752
# weighted avg       0.96      0.96      0.96       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 25***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       422
#            1       0.99      0.98      0.98       330
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.99      0.99       752
# weighted avg       0.99      0.99      0.99       752
#
# ***Trial 26***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       420
#            1       0.98      0.97      0.98       332
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 26***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       420
#            1       0.97      0.97      0.97       332
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 26***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       420
#            1       0.99      0.91      0.95       332
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.95      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 26***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       420
#            1       0.98      0.98      0.98       332
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 27***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       444
#            1       0.98      0.98      0.98       308
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 27***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       444
#            1       0.98      0.97      0.97       308
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 27***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       444
#            1       0.98      0.91      0.94       308
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 27***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       444
#            1       0.98      0.97      0.98       308
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 28***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       410
#            1       1.00      0.97      0.98       342
#
#     accuracy                           0.99       752
#    macro avg       0.99      0.98      0.99       752
# weighted avg       0.99      0.99      0.99       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 28***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       410
#            1       1.00      0.97      0.98       342
#
#     accuracy                           0.98       752
#    macro avg       0.99      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 28***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       410
#            1       0.99      0.89      0.94       342
#
#     accuracy                           0.94       752
#    macro avg       0.95      0.94      0.94       752
# weighted avg       0.95      0.94      0.94       752
#
# ***Trial 28***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       410
#            1       1.00      0.97      0.98       342
#
#     accuracy                           0.98       752
#    macro avg       0.99      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 29***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       437
#            1       0.97      0.98      0.98       315
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 29***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       437
#            1       0.98      0.97      0.97       315
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 29***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       437
#            1       0.99      0.97      0.98       315
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 29***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       437
#            1       0.98      0.98      0.98       315
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 30***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       404
#            1       0.99      0.96      0.97       348
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 30***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       404
#            1       0.99      0.96      0.97       348
#
#     accuracy                           0.97       752
#    macro avg       0.98      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 30***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       404
#            1       0.99      0.91      0.95       348
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.95      0.95       752
#
# ***Trial 30***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       404
#            1       0.99      0.97      0.98       348
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 31***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       434
#            1       0.98      0.97      0.98       318
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 31***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       434
#            1       0.97      0.96      0.97       318
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 31***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       434
#            1       0.98      0.93      0.95       318
#
#     accuracy                           0.96       752
#    macro avg       0.97      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 31***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       434
#            1       0.97      0.97      0.97       318
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 32***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       409
#            1       0.99      0.96      0.98       343
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 32***
# kNN Results:
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       409
#            1       1.00      0.96      0.98       343
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.98      0.98       752
# weighted avg       0.98      0.98      0.98       752
#
# ***Trial 32***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       409
#            1       0.99      0.91      0.95       343
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.95      0.95       752
#
# ***Trial 32***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       409
#            1       0.99      0.96      0.97       343
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752

# %%
# Class balance
print(df['Class'].value_counts(normalize=True))

# Correlation with Class label
print(df.corr()['Class'].sort_values(ascending=False))

# Check if any feature is constant
print((df.drop(columns='Class').nunique() == 1).sum(), "features are constant")
# Out:
# Class
# 0    0.552632
# 1    0.447368
# Name: proportion, dtype: float64
# Class                 1.000000
# Dissimilarity         0.556319
# Skewness              0.402644
# Standard Deviation    0.285568
# Kurtosis              0.239844
# Contrast              0.212643
# Mean                 -0.095729
# Correlation          -0.108601
# Entropy              -0.778180
# Homogeneity          -0.847529
# Energy               -0.862413
# Coarseness                 NaN
# Name: Class, dtype: float64
# 0 features are constant

# %%
df.head()
# Out:
#    Class      Mean  Standard Deviation   Entropy  Skewness   Kurtosis  \
# 0      0  6.535339           24.891522  0.109059  4.276477  18.900575
# 1      0  8.749969           28.389393  0.266538  3.718116  14.464618
# 2      1  7.341095           33.820234  0.001467  5.061750  26.479563
# 3      1  5.958145           30.979219  0.001477  5.677977  33.428845
# 4      0  7.315231           27.010009  0.146761  4.283221  19.079108
#
#      Contrast    Energy  Homogeneity  Dissimilarity  Correlation  \
# 0   98.613971  0.293314     0.530941       4.473346     0.981939
# 1   63.858816  0.475051     0.651352       3.220072     0.988834
# 2   81.867206  0.031917     0.268275       5.981800     0.978014
# 3  151.229741  0.032024     0.243851       7.700919     0.964189
# 4  174.988756  0.343849     0.501140       6.834689     0.972789
#
#       Coarseness
# 0  7.458341e-155
# 1  7.458341e-155
# 2  7.458341e-155
# 3  7.458341e-155
# 4  7.458341e-155

# %%
exp_df_1 = df.drop(['Entropy', 'Kurtosis', 'Contrast', 'Energy', 'Dissimilarity'],axis=1)
exp_df_1.head()
# Out:
#    Class      Mean  Standard Deviation  Skewness  Homogeneity  Correlation  \
# 0      0  6.535339           24.891522  4.276477     0.530941     0.981939
# 1      0  8.749969           28.389393  3.718116     0.651352     0.988834
# 2      1  7.341095           33.820234  5.061750     0.268275     0.978014
# 3      1  5.958145           30.979219  5.677977     0.243851     0.964189
# 4      0  7.315231           27.010009  4.283221     0.501140     0.972789
#
#       Coarseness
# 0  7.458341e-155
# 1  7.458341e-155
# 2  7.458341e-155
# 3  7.458341e-155
# 4  7.458341e-155

# %%
exp_1_train, exp_1_valid, exp_1_test = np.split(exp_df_1.sample(frac=1), [int(0.6*len(exp_df_1)), int(0.8*len(exp_df_1))])

# Scale + oversample only on train
_, X_exp_1_train, y_exp_1_train = scale_dataset(exp_1_train, oversample=True)

# Scale without oversample on valid/test
_, X_exp_1_valid, y_exp_1_valid = scale_dataset(exp_1_valid, oversample=False)
_, X_exp_1_test, y_exp_1_test = scale_dataset(exp_1_test, oversample=False)


LogisticRegressionFunc(X_exp_1_train, y_exp_1_train, X_exp_1_valid, y_exp_1_valid, 33)
KNNFunc(X_exp_1_train, y_exp_1_train, X_exp_1_valid, y_exp_1_valid, 33)
NaiveBayesFunc(X_exp_1_train, y_exp_1_train, X_exp_1_valid, y_exp_1_valid, 33)
SVMFunc(X_exp_1_train, y_exp_1_train, X_exp_1_valid, y_exp_1_valid, 33)
# Out:
# ***Trial 33***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       400
#            1       0.97      0.91      0.94       352
#
#     accuracy                           0.94       752
#    macro avg       0.95      0.94      0.94       752
# weighted avg       0.95      0.94      0.94       752
#
# ***Trial 33***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       400
#            1       0.99      0.91      0.95       352
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.95      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 33***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       400
#            1       0.97      0.87      0.92       352
#
#     accuracy                           0.93       752
#    macro avg       0.93      0.92      0.92       752
# weighted avg       0.93      0.93      0.93       752
#
# ***Trial 33***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       400
#            1       0.97      0.92      0.95       352
#
#     accuracy                           0.95       752
#    macro avg       0.95      0.95      0.95       752
# weighted avg       0.95      0.95      0.95       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
# Class balance
print(exp_df_1['Class'].value_counts(normalize=True))

# Correlation with Class label
print(exp_df_1.corr()['Class'].sort_values(ascending=False))

# Check if any feature is constant
print((exp_df_1.drop(columns='Class').nunique() == 1).sum(), "features are constant")
# Out:
# Class
# 0    0.552632
# 1    0.447368
# Name: proportion, dtype: float64
# Class                 1.000000
# Skewness              0.402644
# Standard Deviation    0.285568
# Mean                 -0.095729
# Correlation          -0.108601
# Homogeneity          -0.847529
# Coarseness                 NaN
# Name: Class, dtype: float64
# 0 features are constant

# %%
exp_df_2 = exp_df_1.drop(['Skewness', 'Standard Deviation'], axis=1)
exp_df_2.head()
# Out:
#    Class      Mean  Homogeneity  Correlation     Coarseness
# 0      0  6.535339     0.530941     0.981939  7.458341e-155
# 1      0  8.749969     0.651352     0.988834  7.458341e-155
# 2      1  7.341095     0.268275     0.978014  7.458341e-155
# 3      1  5.958145     0.243851     0.964189  7.458341e-155
# 4      0  7.315231     0.501140     0.972789  7.458341e-155

# %%
exp_2_train, exp_2_valid, exp_2_test = np.split(exp_df_2.sample(frac=1), [int(0.6*len(exp_df_2)), int(0.8*len(exp_df_2))])

# Scale + oversample only on train
_, X_exp_2_train, y_exp_2_train = scale_dataset(exp_2_train, oversample=True)

# Scale without oversample on valid/test
_, X_exp_2_valid, y_exp_2_valid = scale_dataset(exp_2_valid, oversample=False)
_, X_exp_2_test, y_exp_2_test = scale_dataset(exp_2_test, oversample=False)

LogisticRegressionFunc(X_exp_2_train, y_exp_2_train, X_exp_2_valid, y_exp_2_valid, 34)
KNNFunc(X_exp_2_train, y_exp_2_train, X_exp_2_valid, y_exp_2_valid, 34)
NaiveBayesFunc(X_exp_2_train, y_exp_2_train, X_exp_2_valid, y_exp_2_valid, 34)
SVMFunc(X_exp_2_train, y_exp_2_train, X_exp_2_valid, y_exp_2_valid, 34)
# Out:
# ***Trial 34***
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       419
#            1       0.96      0.97      0.96       333
#
#     accuracy                           0.97       752
#    macro avg       0.97      0.97      0.97       752
# weighted avg       0.97      0.97      0.97       752
#
# ***Trial 34***
# kNN Results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       419
#            1       0.96      0.95      0.96       333
#
#     accuracy                           0.96       752
#    macro avg       0.96      0.96      0.96       752
# weighted avg       0.96      0.96      0.96       752
#
# ***Trial 34***
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       419
#            1       0.97      0.92      0.95       333
#
#     accuracy                           0.95       752
#    macro avg       0.96      0.95      0.95       752
# weighted avg       0.96      0.95      0.95       752
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ***Trial 34***
# Support Vector Machine Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       419
#            1       0.98      0.96      0.97       333
#
#     accuracy                           0.98       752
#    macro avg       0.98      0.97      0.98       752
# weighted avg       0.98      0.98      0.98       752

# %%
# Class balance
print(exp_df_2['Class'].value_counts(normalize=True))

# Correlation with Class label
print(exp_df_2.corr()['Class'].sort_values(ascending=False))

# Check if any feature is constant
print((exp_df_2.drop(columns='Class').nunique() == 1).sum(), "features are constant")
# Out:
# Class
# 0    0.552632
# 1    0.447368
# Name: proportion, dtype: float64
# Class          1.000000
# Mean          -0.095729
# Correlation   -0.108601
# Homogeneity   -0.847529
# Coarseness          NaN
# Name: Class, dtype: float64
# 0 features are constant

# %%
final_df = exp_df_2
final_df.head()
# Out:
#    Class      Mean  Homogeneity  Correlation     Coarseness
# 0      0  6.535339     0.530941     0.981939  7.458341e-155
# 1      0  8.749969     0.651352     0.988834  7.458341e-155
# 2      1  7.341095     0.268275     0.978014  7.458341e-155
# 3      1  5.958145     0.243851     0.964189  7.458341e-155
# 4      0  7.315231     0.501140     0.972789  7.458341e-155

# %%
final_train, final_valid, final_test = np.split(final_df.sample(frac=1), [int(0.6*len(final_df)), int(0.8*len(final_df))])

_, X_final_train, y_final_train = scale_dataset(final_train, oversample=True)
_, X_final_valid, y_final_valid = scale_dataset(final_valid, oversample=False)
_, X_final_test, y_final_test = scale_dataset(final_test, oversample=False)
lr_final_model = LogisticRegression()
lr_final_model = lr_final_model.fit(X_final_train, y_final_train)
# Out:
# C:\Users\aneyk\anaconda3\envs\tf_cpu\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
final_features = ['Mean', 'Homogeneity', 'Correlation', 'Coarseness']
explainer = shap.Explainer(lr_final_model, X_final_train, feature_names = final_features)
shap_values = explainer(X_final_test)

# %%
shap.summary_plot(shap_values, X_final_test, feature_names=final_features)
